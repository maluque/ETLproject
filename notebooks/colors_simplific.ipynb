# %% [markdown]
# ### dictionary for simplification of colors used in ASOS API

# %%
color_simplification = {
    'tierra_oscura': 'marron',
    'multicolor': 'multicolor',
    'sidra': 'naranja',
    'key_largo': 'blanco',
    'leopardo': 'estampado',
    'crudo': 'beis',
    'estrella_corazon_simbolo_de_la_paz': 'estampado',
    'marga_avena': 'marron',
    'dalia': 'morado',
    'piedra': 'marron',
    'lila': 'morado',
    'violeta': 'morado',
    'burdeos': 'marron',
    'crema': 'crema',
    'corazon_de_acero': 'gris',
    'camiseta_sin_mangas_de_canale_wilderville': 'blanco',
    'carbon_lavado': 'negro',
    'caqui': 'beis',
    'tostado': 'marron',
    'pizarra': 'gris',
    'black': 'negro',
    'natural': 'beis',
    'negro': 'negro',
    'dorado ambar': 'dorado',
    'tierra oscura': 'marron',
    'blanco nieve': 'blanco',
    'verde oscuro': 'verde',
    'negro descolorido': 'negro',
    'blanco desgastado': 'blanco',
    'verde': 'verde',
    'rosa': 'rosa',
    'key largo': 'blanco',
    'blanco': 'blanco',
    'blanco optico': 'blanco',
    'rojo': 'rojo',
    'blanco puro': 'blanco',
    'blanco leche': 'blanco',
    'estrella corazon simbolo de la paz': 'estampado',
    'marron': 'marron',
    'marga avena': 'marron',
    'gris claro': 'gris',
    'naranja quemado': 'naranja',
    'naranja': 'naranja',
    'verde lima': 'verde',
    'marron oscuro': 'marron',
    'verde claro': 'verde',
    'blancoblanco': 'blanco',
    'azul': 'azul',
    'blanco con diseno de mickey': 'estampado',
    'gris espumoso': 'gris',
    'gris marga': 'gris',
    'gris': 'gris',
    'azul marinoazul': 'azul',
    'corazon de acero': 'gris',
    'camiseta sin mangas de canale wilderville': 'blanco',
    'gris desgastado': 'gris',
    'carbon lavado': 'negro',
    'blanco estampado': 'blanco',
    'rosa intenso': 'rosa',
    'marron bombay': 'marron',
    'negro tnf': 'negro',
    'amarillo': 'amarillo',
    'gris jaspeado y crema': 'gris',
    'rosa claro': 'rosa',
    'azul claro': 'azul',
    'marron topo': 'marron',
    'negro lago intenso': 'negro',
    'blanco verde manzana mentaverde': 'blanco',
    'azul oceano intenso': 'azul',
    'verde y crema': 'verde',
    'salvia apagado': 'verde',
    'blanco y marron': 'blanco',
    'violeta multicolor': 'morado',
    'blanco hueso': 'blanco',
    'rosa tenue': 'rosa',
    'marron claro': 'marron',
    'color moca y crema': 'marron',
    'verde desgastado': 'verde',
    'plateado': 'plateado',
    'azul polvoriento': 'azul',
    'azul medio': 'azul',
    'neutro': 'neutro',
    'soldado': 'verde',
    'ladrillo con fuego': 'marron',
    'verde militar': 'verde',
    'a00 + corazon rojorojo': 'rojo',
    'monocromatico': 'multicolor',
    'flores azulesazul': 'azul',
    'verde medio': 'verde',
    'beis': 'beis',
    'gris melange medio': 'gris',
    'rayas azulesazul': 'estampado',
    'beis claro': 'beis',
    'marfil': 'beis',
    'azul pastel': 'azul',
    'turquesa pastel': 'turquesa',
    "oscuro con logo levi's brillante": 'negro',
    "logo levi's de pedreria": 'negro',
    'tan': 'marron',
    'marron chocolate': 'marron',
    'coral': 'coral',
    'blanco tnf': 'blanco',
    'azul marino': 'azul',
    'negro desgastado': 'negro',
    'azul cerceta': 'azul',
    'estampado marron': 'estampado',
    'multicolor neutro': 'multicolor',
    'caqui dickies': 'beis',
    'dorado': 'dorado',
    'caqui gris jaspeadogris': 'beis',
    'camel': 'marron',
    'deep lake': 'azul',
    'brown': 'marron',
    'blanco y rojorojo': 'blanco',
    'negro lavado': 'negro',
    'negro abstracto': 'negro',
    'ssnl luminoso': 'multicolor',
    'blanco luz solar': 'blanco',
    'verde apagado': 'verde',
    'gris carbon': 'gris',
    'combinacion clasica': 'multicolor',
    'crema 021': 'crema',
    'crema irlandesa': 'crema',
    'color hueso': 'beis',
    'cascara de huevo': 'blanco',
    'lavado oscuro envejecido go': 'negro',
    'antracita': 'negro',
    'blanco rosa luminosorosa': 'blanco',
    'denim medio': 'azul',
    'rayas crema': 'estampado',
    'crudo con estampado "marseille hotel"': 'estampado',
    'amarillo estampado artistico': 'amarillo',
    'piedra pomez': 'marron',
    'morado': 'morado',
    'rosa begonia': 'rosa',
    'nenufar': 'verde',
    'blanco negro rojonegrorojo': 'multicolor',
    'lavanda  negronegro': 'lila',
    "camiseta blanca con estampado floral de levi's": 'blanco',
    'naranjanaranja': 'naranja',
    'marga hielo': 'marron',
    'blanco estampado de postal': 'blanco',
    'salvia': 'verde',
    'tofu perla': 'blanco',
    'cloud dancer': 'blanco',
    'arena': 'beis',
    'chocolate': 'marron',
    'arena claro a rayas': 'beis',
    'lima': 'verde',
    'simbolo de la paz floral': 'rosa',
    'marga coral': 'rosa',
    'vison': 'gris',
    'avena jaspeado': 'beis',
    'rayas blancas': 'blanco',
    'hey friend 4': 'multicolor',
    'vainilla francesa': 'blanco',
    'lavanda jaspeado': 'lila',
    'estampado floral artesano': 'floral',
    'logo deportivo minimalista': 'negro',
    'logo serif': 'negro',
    'rayas rojas veraniegas': 'rojo',
    'licencia mickey mouse': 'multicolor',
    'desert sage': 'verde',
    'violeta pastel': 'lila',
    'abstracto multicolor': 'multicolor',
    'desert sand': 'beis',
    'guijarro': 'gris',
    'rayas monocolor': 'multicolor',
    'pinksicle': 'rosa',
    'fluro orange': 'naranja',
    'hueso': 'blanco',
    'impala': 'negro',
    'lavanda pastel': 'lila',
    'melocoton melba': 'naranja',
    'surf spray': 'azul',
    'estampado de cuadros vichy': 'estampado',
    'florecitas rojas': 'rojo',
    'carbon': 'negro',
    'lima claro': 'verde',
    'mostaza': 'amarillo',
    'paprika': 'rojo',
    'mustard': 'amarillo',
    'lila pastel': 'lila',
    'oliva neutro': 'verde',
    'hueso happy pino': 'blanco',
    'crema avena': 'blanco',
    'burdeos intenso': 'rojo',
    'oliva': 'verde',
    'tonos neutros': 'gris',
    'albaricoque': 'naranja',
    'estampado de rayas finas': 'estampado',
    'camel tofe': 'marron',
    'mocha': 'marron',
    'ciruela': 'morado',
    'melocoton': 'naranja',
    'rayas': 'multicolor',
    'mariposa cosmica': 'multicolor',
    'sorbete de lima': 'verde',
    'avena': 'beis',
    'limon': 'amarillo',
    'oliva suave': 'verde',
    'malva': 'lila',
    'crepusculo': 'azul',
    'sunset gold': 'amarillo',
    'aqua': 'verde',
    'color teja': 'marron',
    'de barbour beacon': 'negro',
    'menta': 'verde',
    'cargo': 'verde',
    'brunette': 'marron',
    'aguamarina polvoreada': 'verde',
    'nube': 'gris',
    'hortensia': 'azul',
    'zanahoria lechuga': 'naranja',
    'estampado integral lima': 'estampado',
    'estampado monocromatico': 'estampado',
    'ash': 'gris',
    'pink soda': 'rosa',
    'arcilla coral': 'naranja',
    'nogal': 'marron',
    'jacquard vison': 'gris',
    'malva dulce': 'lila',
    'cebra multicolor abstracta': 'multicolor',
    'diseno a cuadros de efecto tie dye': 'estampado',
    'estampado de cebra': 'estampado',
    'estampado de cuadros tipo cuadricula': 'estampado',
    'rocio de orquidea': 'rosa',
    'fluor lavado': 'rosa',
    'flamin go': 'naranja',
    'frambuesa': 'rojo',
    'arena blanca': 'beis',
    'carmesi intenso': 'rojo',
    'malva pradera': 'lila',
    'color crudo gofrado': 'beis',
    'berenjena': 'morado',
    'jengibre': 'naranja',
    'topo': 'marron',
    'castano miel': 'marron',
    'bata monks': 'multicolor',
    'teja': 'marron',
    'cerceta lima': 'verde',
    'charisma': 'multicolor',
    'tango mandarina': 'naranja',
    'halcon': 'negro',
    'violeta oscuro': 'violeta',
    'rayas negras': 'multicolor',
    'animal violeta': 'violeta',
    'musgo floral': 'verde',
    'rayas melocoton melba': 'multicolor',
    'total eclipse': 'negro',
    'estampado floral': 'floral',
    'estampado geometrico': 'estampado',
    'plateado porcelana': 'gris',
    'guijarro lavado': 'beis',
'lila pizarra': 'lila',
    'chocolate oscuro': 'marron',
    'antracita marga': 'gris',
    'camel marga': 'marron',
    'cascara de coco': 'marron',
    'acai': 'morado',
    'fucsia': 'rosa',
    'galleta': 'beis',
    'rayas cerveza de raiz': 'multicolor',
    'violeta marga': 'violeta',
    'caqui crema antiguo': 'beis',
    'jacaranda gigi': 'lila',
    'tofu': 'blanco',
    'pera': 'verde',
    'serpiente': 'multicolor',
    'chocolate y lima': 'marron',
    'caviar': 'negro',
    'estampado leopardo': 'estampado',
    'vino': 'rojo',
    'polvo del sahara': 'beis',
    'violeta claro': 'violeta',
    'combo guapo': 'multicolor',
    'brillo lila': 'lila',
    'arcilla': 'marron',
    'violeta fucsia': 'violeta',
    'margaritas de croche': 'multicolor',
    'glicinia oscuro': 'violeta',
    'oxido': 'marron',
    'lila liso': 'lila',
    'animal': 'multicolor',
    'semilla de camomila': 'amarillo',
    'explosion floral': 'floral',
    'cantalupo': 'naranja',
    'caqui lavado': 'marron',
    'malvavisco': 'rosa',
    'orquidea': 'violeta',
    'salvia lavado acido': 'verde',
    'marmol': 'blanco',
    'rayas amarillas': 'amarillo',
    'arena savannah multicolor': 'multicolor',
    'tomate': 'rojo',
    'taffy': 'rosa',
    'manzana': 'verde',
    'halomint': 'verde',
    'lavado a la piedra': 'gris',
    'estampado': 'estampado',
    'sky tint': 'azul',
    'twilight navy': 'azul',
    'blue': 'azul',
    'white': 'blanco',
    'caqui  crema antiguo': "marron"}

# %%
import pickle

# Save the object to a file using pickle
with open('color_simplification.pkl', 'wb') as file:
    pickle.dump(color_simplification, file)
